# %% [markdown]
# # Feature Analysis
#
# This notebook used for analysis the distribution of designed features.

# %%
import pandas as pd
from pathlib import Path
from matplotlib import pyplot as plt

# %%
DATA_DIR = Path('../data/data-for-processing')
CLEANED_DATA_LIST = list(DATA_DIR.glob('cleaned_*.feather'))
print(CLEANED_DATA_LIST)
# Out:
# [PosixPath('../data/data-for-processing/cleaned_chunk_001_train.feather'), PosixPath('../data/data-for-processing/cleaned_chunk_009_train.feather'), PosixPath('../data/data-for-processing/cleaned_test.feather'), PosixPath('../data/data-for-processing/cleaned_chunk_005_train.feather'), PosixPath('../data/data-for-processing/cleaned_chunk_003_train.feather'), PosixPath('../data/data-for-processing/cleaned_chunk_011_train.feather'), PosixPath('../data/data-for-processing/cleaned_chunk_006_train.feather'), PosixPath('../data/data-for-processing/cleaned_chunk_002_train.feather'), PosixPath('../data/data-for-processing/cleaned_chunk_000_train.feather'), PosixPath('../data/data-for-processing/cleaned_chunk_010_train.feather'), PosixPath('../data/data-for-processing/cleaned_chunk_004_train.feather'), PosixPath('../data/data-for-processing/cleaned_chunk_007_train.feather'), PosixPath('../data/data-for-processing/cleaned_chunk_008_train.feather')]

# %%
df = pd.read_feather(CLEANED_DATA_LIST[0])
df.columns
# Out:
# /home/solomon/anaconda3/envs/py3/lib/python3.6/site-packages/pandas/io/feather_format.py:112: FutureWarning: `nthreads` argument is deprecated, pass `use_threads` instead
#   return feather.read_dataframe(path, nthreads=nthreads)
# Index(['level_0', 'index', 'key', 'fare_amount', 'pickup_datetime',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count', 'pickup_timezone',
#        'pickup_datetime_obj', 'pickup_year', 'pickup_month', 'pickup_day',
#        'pickup_hour', 'pickup_minute', 'pickup_second', 'pickup_weekday',
#        'airport_jfk', 'airport_lga', 'airport_ewr', 'pickup_dropoff_distance'],
#       dtype='object')

# %%
for file_path in CLEANED_DATA_LIST:
    print('%s'%(file_path,))
    print('-'*30)
    df = pd.read_feather(file_path)
    print(df['pickup_timezone'].value_counts())
    print('-'*30)
    print(df['airport_jfk'].value_counts())
    print('-'*30)
    print(df['airport_lga'].value_counts())
    print('-'*30)
    print(df['airport_ewr'].value_counts())
    print('='*30)
# Out:
# ../data/data-for-processing/cleaned_chunk_001_train.feather
# ------------------------------
# /home/solomon/anaconda3/envs/py3/lib/python3.6/site-packages/pandas/io/feather_format.py:112: FutureWarning: `nthreads` argument is deprecated, pass `use_threads` instead
#   return feather.read_dataframe(path, nthreads=nthreads)
# UTC    4981700
# Name: pickup_timezone, dtype: int64
# ------------------------------
# 0    4928703
# 1      52997
# Name: airport_jfk, dtype: int64
# 0    4827256
# 1     154444
# Name: airport_lga, dtype: int64
# 0    4975305
# 1       6395
# Name: airport_ewr, dtype: int64
# ...
# ../data/data-for-processing/cleaned_chunk_009_train.feather
# ------------------------------
# UTC    4982056
# Name: pickup_timezone, dtype: int64
# ------------------------------
# 0    4929408
# 1      52648
# Name: airport_jfk, dtype: int64
# 0    4826579
# 1     155477
# Name: airport_lga, dtype: int64
# 0    4975517
# 1       6539
# Name: airport_ewr, dtype: int64
# ...

# %%
for file_path in CLEANED_DATA_LIST:
    print('%s'%(file_path,))
    print('-'*30)
    df = pd.read_feather(file_path)
    print(df['pickup_dropoff_distance'].value_counts())
    print('='*30)
# Out:
# ../data/data-for-processing/cleaned_chunk_001_train.feather
# ------------------------------
# /home/solomon/anaconda3/envs/py3/lib/python3.6/site-packages/pandas/io/feather_format.py:112: FutureWarning: `nthreads` argument is deprecated, pass `use_threads` instead
#   return feather.read_dataframe(path, nthreads=nthreads)
# 0.000000       142384
# 0.000222          128
# 0.000111          124
# 0.000334           80
# 0.000424           51
# 0.000556           49
# 0.000445           34
# 0.000848           21
# 0.001112           20
# 0.000890           19
# 8713.610352        18
# 0.000778           18
# 0.001273           12
# 0.002002           11
# 0.011119           10
# 8666.613281         8
# 8665.383789         8
# 8666.605469         8
# 0.001334            8
# 8667.099609         8
# 8665.969727         8
# 0.000667            8
# 8666.686523         7
# 8664.833008         7
# 8667.547852         7
# 8665.855469         7
# 0.001446            7
# 8665.916016         7
# ...

# %%
df.loc[df['pickup_dropoff_distance']==0, :].head(10)
# Out:
#      level_0     index                            key  fare_amount  \
# 27        27  40000027    2014-04-13 17:45:16.0000002         10.5
# 54        54  40000054    2009-01-01 22:38:55.0000001         12.6
# 62        62  40000062   2011-10-28 00:00:00.00000074          5.3
# 100      100  40000100   2009-08-23 21:29:00.00000091          8.9
# 106      106  40000106    2015-02-04 09:17:38.0000005         60.0
# 108      108  40000108  2011-04-27 22:45:00.000000154         11.3
# 110      110  40000110    2013-10-10 22:02:24.0000009          4.5
# 114      114  40000114  2011-07-26 17:23:00.000000137          4.1
# 132      132  40000132   2010-05-14 13:31:00.00000076         10.9
# 152      152  40000152   2013-06-30 11:01:00.00000024          9.0
#
#              pickup_datetime  pickup_longitude  pickup_latitude  \
# 27   2014-04-13 17:45:16 UTC          0.000000         0.000000
# 54   2009-01-01 22:38:55 UTC          0.000000         0.000000
# ...

# %%
df.loc[(df['pickup_longitude']==df['dropoff_longitude']) & (df['pickup_latitude']==df['dropoff_latitude'])
       & (df['pickup_longitude']!=0) & (df['pickup_latitude']!=0), :].head(10)
# Out:
#      level_0     index                            key  fare_amount  \
# 100      100  40000100   2009-08-23 21:29:00.00000091          8.9
# 106      106  40000106    2015-02-04 09:17:38.0000005         60.0
# 110      110  40000110    2013-10-10 22:02:24.0000009          4.5
# 352      353  40000353    2010-10-03 10:22:39.0000005         12.5
# 384      385  40000385    2009-08-14 01:19:00.0000005          7.7
# 402      404  40000404    2013-05-13 21:03:33.0000001          8.0
# 527      529  40000529  2013-11-07 08:40:00.000000247          7.0
# 588      590  40000590  2009-12-11 22:13:00.000000243          5.7
# 682      684  40000684    2013-01-18 15:57:42.0000003          2.5
# 702      704  40000704    2014-08-09 00:17:06.0000009          2.5
#
#              pickup_datetime  pickup_longitude  pickup_latitude  \
# 100  2009-08-23 21:29:00 UTC        -74.000797        40.762248
# 106  2015-02-04 09:17:38 UTC        -74.032951        40.717110
# ...

# %%
TRAIN_DATA = DATA_DIR / 'cleaned_chunk_000_train.feather'
TEST_DATA = DATA_DIR / 'cleaned_test.feather'
train_df = pd.read_feather(TRAIN_DATA)
test_df = pd.read_feather(TEST_DATA)
# Out:
# /home/solomon/anaconda3/envs/py3/lib/python3.6/site-packages/pandas/io/feather_format.py:112: FutureWarning: `nthreads` argument is deprecated, pass `use_threads` instead
#   return feather.read_dataframe(path, nthreads=nthreads)

# %%
train_df.loc[:, ['key', 'pickup_datetime_utc', 'pickup_datetime_local', 'pickup_day', 'pickup_hour']].head(20)
# Out:
#                               key       pickup_datetime_utc  \
# 0     2009-06-15 17:26:21.0000001 2009-06-15 17:26:21+00:00
# 1     2010-01-05 16:52:16.0000002 2010-01-05 16:52:16+00:00
# 2    2011-08-18 00:35:00.00000049 2011-08-18 00:35:00+00:00
# 3     2012-04-21 04:30:42.0000001 2012-04-21 04:30:42+00:00
# 4   2010-03-09 07:51:00.000000135 2010-03-09 07:51:00+00:00
# 5     2011-01-06 09:50:45.0000002 2011-01-06 09:50:45+00:00
# 6     2012-11-20 20:35:00.0000001 2012-11-20 20:35:00+00:00
# 7    2012-01-04 17:22:00.00000081 2012-01-04 17:22:00+00:00
# 8   2012-12-03 13:10:00.000000125 2012-12-03 13:10:00+00:00
# 9    2009-09-02 01:11:00.00000083 2009-09-02 01:11:00+00:00
# 10    2012-04-08 07:30:50.0000002 2012-04-08 07:30:50+00:00
# 11   2012-12-24 11:24:00.00000098 2012-12-24 11:24:00+00:00
# 12    2009-11-06 01:04:03.0000002 2009-11-06 01:04:03+00:00
# 13  2013-07-02 19:54:00.000000232 2013-07-02 19:54:00+00:00
# 14    2011-04-05 17:11:05.0000001 2011-04-05 17:11:05+00:00
# ...

# %%
te_df.loc[:, ['key', 'pickup_datetime_utc', 'pickup_datetime_local', 'pickup_day', 'pickup_hour']].head(20)

# %%
test_df['pickup_dropoff_distance'].plot(kind='hist', bins=100)

# %%
test_df.loc[(test_df['pickup_longitude']==0) | (test_df['pickup_latitude']==0), :]
# Out:
# Empty DataFrame
# Columns: [index, key, pickup_datetime, pickup_longitude, pickup_latitude, dropoff_longitude, dropoff_latitude, passenger_count, pickup_timezone, pickup_datetime_obj, pickup_year, pickup_month, pickup_day, pickup_hour, pickup_minute, pickup_second, pickup_weekday, airport_jfk, airport_lga, airport_ewr, pickup_dropoff_distance]
# Index: []
#
# [0 rows x 21 columns]

# %%
test_df.loc[(test_df['dropoff_longitude']==0) | (test_df['dropoff_latitude']==0), :]
# Out:
# Empty DataFrame
# Columns: [index, key, pickup_datetime, pickup_longitude, pickup_latitude, dropoff_longitude, dropoff_latitude, passenger_count, pickup_timezone, pickup_datetime_obj, pickup_year, pickup_month, pickup_day, pickup_hour, pickup_minute, pickup_second, pickup_weekday, airport_jfk, airport_lga, airport_ewr, pickup_dropoff_distance]
# Index: []
#
# [0 rows x 21 columns]

# %%
test_df.loc[(test_df['pickup_longitude']==test_df['dropoff_longitude']) & (test_df['pickup_latitude']==test_df['dropoff_latitude']), :]
# Out:
#       index                            key          pickup_datetime  \
# 121     121  2014-06-14 13:39:00.000000191  2014-06-14 13:39:00 UTC
# 279     279    2010-09-05 22:31:32.0000002  2010-09-05 22:31:32 UTC
# 318     318  2009-06-10 16:55:00.000000131  2009-06-10 16:55:00 UTC
# 417     417  2011-06-24 12:03:00.000000145  2011-06-24 12:03:00 UTC
# 423     423   2011-06-24 12:03:00.00000086  2011-06-24 12:03:00 UTC
# 434     434  2011-06-24 12:03:00.000000173  2011-06-24 12:03:00 UTC
# 451     451   2011-06-24 12:03:00.00000047  2011-06-24 12:03:00 UTC
# 491     491   2011-06-24 12:03:00.00000076  2011-06-24 12:03:00 UTC
# 498     498   2011-06-24 12:03:00.00000051  2011-06-24 12:03:00 UTC
# 666     666    2012-11-11 20:35:40.0000002  2012-11-11 20:35:40 UTC
# 781     781  2011-06-01 07:37:00.000000212  2011-06-01 07:37:00 UTC
# 860     860  2010-08-27 18:45:00.000000196  2010-08-27 18:45:00 UTC
# 943     943    2011-02-12 00:43:24.0000001  2011-02-12 00:43:24 UTC
# ...

# %%
train_df.loc[(train_df['pickup_longitude']==train_df['dropoff_longitude']) & (train_df['pickup_latitude']==train_df['dropoff_latitude']), :]
# Out:
#          level_0    index                            key  fare_amount  \
# 2              2  5000002   2012-12-09 18:03:00.00000057        98.75
# 6              6  5000006    2009-10-15 07:17:59.0000001         6.10
# 18            18  5000018  2011-06-07 22:32:00.000000129        15.70
# 68            68  5000068    2010-08-11 22:35:47.0000003        13.70
# 92            92  5000092  2014-03-27 12:44:00.000000177         6.00
# 137          137  5000137  2014-06-25 18:53:00.000000126         6.00
# 155          155  5000155    2013-06-01 16:20:38.0000001         4.00
# 157          157  5000157    2010-12-23 18:10:17.0000002         7.30
# 234          234  5000234  2010-03-25 21:48:00.000000250        53.00
# 236          236  5000236    2009-11-06 21:12:43.0000006         9.30
# 261          261  5000261    2010-09-19 15:29:17.0000004         9.30
# 267          267  5000267   2011-05-31 20:50:00.00000083         8.50
# ...
