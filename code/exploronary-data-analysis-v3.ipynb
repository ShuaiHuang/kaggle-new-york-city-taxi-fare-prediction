# %%
import pandas as pd

# %%
TRAIN_DATA = '../data/data-for-processing/cleaned_train.feather'
TEST_DATA = '../data/data-for-processing/cleaned_test.feather'
pd.set_option('max_columns', 50)

# %%
train_df = pd.read_feather(TRAIN_DATA)
test_df = pd.read_feather(TEST_DATA)
# Out:
# /home/solomon/anaconda3/envs/py3/lib/python3.6/site-packages/pandas/io/feather_format.py:112: FutureWarning: `nthreads` argument is deprecated, pass `use_threads` instead
#   return feather.read_dataframe(path, nthreads=nthreads)

# %%
train_df.head(10)
# Out:
#                              key  fare_amount     pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5 2009-06-15 17:26:21
# 1    2010-01-05 16:52:16.0000002         16.9 2010-01-05 16:52:16
# 2   2011-08-18 00:35:00.00000049          5.7 2011-08-18 00:35:00
# 3    2012-04-21 04:30:42.0000001          7.7 2012-04-21 04:30:42
# 4  2010-03-09 07:51:00.000000135          5.3 2010-03-09 07:51:00
# 5    2011-01-06 09:50:45.0000002         12.1 2011-01-06 09:50:45
# 6    2012-11-20 20:35:00.0000001          7.5 2012-11-20 20:35:00
# 7   2012-01-04 17:22:00.00000081         16.5 2012-01-04 17:22:00
# 8  2012-12-03 13:10:00.000000125          9.0 2012-12-03 13:10:00
# 9   2009-09-02 01:11:00.00000083          8.9 2009-09-02 01:11:00
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0         -1.288826         0.710721          -1.288779          0.710563
# 1         -1.291824         0.710546          -1.291182          0.711780
# ...

# %%
test_df.head(10)
# Out:
#                            key     pickup_datetime  pickup_longitude  \
# 0  2015-01-27 13:08:24.0000002 2015-01-27 13:08:24         -1.291078
# 1  2015-01-27 13:08:24.0000003 2015-01-27 13:08:24         -1.291314
# 2  2011-10-08 11:53:44.0000002 2011-10-08 11:53:44         -1.291239
# 3  2012-12-01 21:12:12.0000002 2012-12-01 21:12:12         -1.291215
# 4  2012-12-01 21:12:12.0000003 2012-12-01 21:12:12         -1.290951
# 5  2012-12-01 21:12:12.0000005 2012-12-01 21:12:12         -1.290863
# 6  2011-10-06 12:10:20.0000001 2011-10-06 12:10:20         -1.290654
# 7  2011-10-06 12:10:20.0000003 2011-10-06 12:10:20         -1.287656
# 8  2011-10-06 12:10:20.0000002 2011-10-06 12:10:20         -1.291790
# 9  2014-02-18 15:22:20.0000002 2014-02-18 15:22:20         -1.291013
#
#    pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0         0.711463          -1.291220          0.711114                1
# ...

# %%
train_df.loc[:, 'reserved_flag'].value_counts()
# Out:
# 0    97
# 2     3
# Name: reserved_flag, dtype: int64

# %%
train_df.loc[:, 'pickup_year'].value_counts()
# Out:
# 2011    22
# 2013    17
# 2012    16
# 2014    13
# 2010    12
# 2009    12
# 2015     8
# Name: pickup_year, dtype: int64

# %%
test_df.loc[:, 'pickup_year'].value_counts()
# Out:
# 2011    2055
# 2014    1902
# 2010    1753
# 2012    1428
# 2013    1135
# 2009    1022
# 2015     619
# Name: pickup_year, dtype: int64

# %%
train_df.columns
# Out:
# Index(['key', 'fare_amount', 'pickup_datetime', 'pickup_longitude',
#        'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',
#        'passenger_count', 'reserved_flag', 'pickup_datetime_utc',
#        'pickup_datetime_local', 'pickup_year', 'pickup_month', 'pickup_day',
#        'pickup_hour', 'pickup_minute', 'pickup_second', 'pickup_weekday',
#        'pickup_days_in_year', 'pickup_days_sin', 'pickup_days_cos',
#        'pickup_seconds_in_day', 'pickup_seconds_sin', 'pickup_seconds_cos',
#        'pickup_weekday_sin', 'pickup_weekday_cos', 'pickup_time_class',
#        'pickup_mha', 'dropoff_mha', 'mha_flag', 'longitude_delta',
#        'latitude_delta', 'haver_dist', 'bear_dist', 'jfk_dist', 'ewr_dist',
#        'lga_dist', 'liberty_dist', 'nyc_dist'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['key', 'pickup_datetime', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'passenger_count',
#        'pickup_datetime_utc', 'pickup_datetime_local', 'pickup_year',
#        'pickup_month', 'pickup_day', 'pickup_hour', 'pickup_minute',
#        'pickup_second', 'pickup_weekday', 'pickup_days_in_year',
#        'pickup_days_sin', 'pickup_days_cos', 'pickup_seconds_in_day',
#        'pickup_seconds_sin', 'pickup_seconds_cos', 'pickup_weekday_sin',
#        'pickup_weekday_cos', 'pickup_time_class', 'pickup_mha', 'dropoff_mha',
#        'mha_flag', 'longitude_delta', 'latitude_delta', 'haver_dist',
#        'bear_dist', 'jfk_dist', 'ewr_dist', 'lga_dist', 'liberty_dist',
#        'nyc_dist'],
#       dtype='object')

# %%
TRAIN_DATA = '../data/data-for-training/cleaned_train.feather'
TEST_DATA = '../data/data-for-training/cleaned_test.feather'
train_df = pd.read_feather(TRAIN_DATA)
test_df = pd.read_feather(TEST_DATA)
# Out:
# /home/solomon/anaconda3/envs/py3/lib/python3.6/site-packages/pandas/io/feather_format.py:112: FutureWarning: `nthreads` argument is deprecated, pass `use_threads` instead
#   return feather.read_dataframe(path, nthreads=nthreads)

# %%
train_df.head()
# Out:
#                              key  pickup_longitude  pickup_latitude  \
# 0    2009-06-15 17:26:21.0000001         -1.288826         0.710721
# 1    2010-01-05 16:52:16.0000002         -1.291824         0.710546
# 2   2011-08-18 00:35:00.00000049         -1.291242         0.711418
# 3    2012-04-21 04:30:42.0000001         -1.291319         0.710927
# 4  2010-03-09 07:51:00.000000135         -1.290987         0.711536
#
#    dropoff_longitude  dropoff_latitude  passenger_count  pickup_days_sin  \
# 0          -1.288779          0.710563                1         0.296713
# 1          -1.291182          0.711780                1         0.068802
# 2          -1.291391          0.711231                2        -0.705584
# 3          -1.291396          0.711363                1         0.942761
# 4          -1.290787          0.711811                1         0.914128
#
#    pickup_days_cos  pickup_seconds_sin  pickup_seconds_cos  \
# ...

# %%
test_df.head()
# Out:
#                            key  pickup_longitude  pickup_latitude  \
# 0  2015-01-27 13:08:24.0000002         -1.291078         0.711463
# 1  2015-01-27 13:08:24.0000003         -1.291314         0.710687
# 2  2011-10-08 11:53:44.0000002         -1.291239         0.711244
# 3  2012-12-01 21:12:12.0000002         -1.291215         0.711532
# 4  2012-12-01 21:12:12.0000003         -1.290951         0.711916
#
#    dropoff_longitude  dropoff_latitude  passenger_count  pickup_days_sin  \
# 0          -1.291220          0.711114                1         0.432776
# 1          -1.291524          0.711033                1         0.432776
# 2          -1.291189          0.711154                1        -0.994218
# 3          -1.291377          0.711250                1        -0.493776
# 4          -1.291344          0.711124                1        -0.493776
#
#    pickup_days_cos  pickup_seconds_sin  pickup_seconds_cos  \
# 0         0.901502            0.847122           -0.531399
# ...
